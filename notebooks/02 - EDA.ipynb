# %%
import pandas as pd
import numpy as np
import os

# remove column restrictions
pd.options.display.max_columns = None

# default float instead of scientific notation
pd.options.display.float_format = '{:,.2f}'.format

# %%
data_path = '../data/raw'
file_path = os.path.join(data_path, 'TradeData_8_2_2025_13_44_38.csv')

# %%
# read csv
df = pd.read_csv(file_path, encoding="latin-1", engine="python")

# %% [markdown]
# ### Check completeness

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, C to C
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   typeCode                  100000 non-null  object
#  1   freqCode                  100000 non-null  int64
#  2   refPeriodId               100000 non-null  int64
#  3   refYear                   100000 non-null  int64
#  4   refMonth                  100000 non-null  int64
#  5   period                    100000 non-null  int64
#  6   reporterCode              100000 non-null  object
#  7   reporterISO               100000 non-null  object
#  8   reporterDesc              100000 non-null  object
#  9   flowCode                  100000 non-null  object
#  10  flowDesc                  100000 non-null  int64
#  11  partnerCode               100000 non-null  object
#  12  partnerISO                100000 non-null  object
#  13  partnerDesc               100000 non-null  int64
#  14  partner2Code              100000 non-null  object
#  15  partner2ISO               100000 non-null  object
#  16  partner2Desc              100000 non-null  object
#  17  classificationCode        100000 non-null  object
#  18  classificationSearchCode  100000 non-null  bool
#  19  isOriginalClassification  100000 non-null  object
#  20  cmdCode                   100000 non-null  object
#  21  cmdDesc                   100000 non-null  int64
#  22  aggrLevel                 100000 non-null  bool
#  23  isLeaf                    100000 non-null  object
#  24  customsCode               100000 non-null  object
#  25  customsDesc               100000 non-null  int64
#  26  mosCode                   100000 non-null  int64
#  27  motCode                   100000 non-null  object
#  28  motDesc                   100000 non-null  int64
#  29  qtyUnitCode               0 non-null       float64
#  30  qtyUnitAbbr               100000 non-null  int64
#  31  qty                       100000 non-null  bool
#  32  isQtyEstimated            100000 non-null  int64
#  33  altQtyUnitCode            0 non-null       float64
#  34  altQtyUnitAbbr            100000 non-null  int64
#  35  altQty                    100000 non-null  bool
#  36  isAltQtyEstimated         98991 non-null   float64
#  37  netWgt                    100000 non-null  bool
#  38  isNetWgtEstimated         100000 non-null  int64
#  39  grossWgt                  100000 non-null  bool
#  40  isGrossWgtEstimated       75161 non-null   float64
#  41  cifvalue                  76119 non-null   float64
#  42  fobvalue                  100000 non-null  float64
#  43  primaryValue              100000 non-null  int64
#  44  legacyEstimationFlag      100000 non-null  bool
#  45  isReported                100000 non-null  bool
#  46  isAggregate               0 non-null       float64
# dtypes: bool(8), float64(7), int64(16), object(16)
# memory usage: 31.3+ MB
# None

# %%
# get missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]

print("Missing Values in Each Column:")
print(missing_values)
print("Missing values percentage: ")
print((missing_values / df.shape[0]) * 100)
# Out:
# Missing Values in Each Column:
# qtyUnitCode            100000
# altQtyUnitCode         100000
# isAltQtyEstimated        1009
# isGrossWgtEstimated     24839
# cifvalue                23881
# isAggregate            100000
# dtype: int64
# Missing values percentage:
# qtyUnitCode           100.00
# altQtyUnitCode        100.00
# isAltQtyEstimated       1.01
# isGrossWgtEstimated    24.84
# cifvalue               23.88
# isAggregate           100.00
# dtype: float64

# %%
# remove rows with at least 50% missing values
threshold = 0.5 * df.shape[1]
df_cleaned = df.dropna(thresh=threshold)

# %% [markdown]
# ### Numeric summary

# %%
display(df.describe().T)
# Out:
#                          count             mean               std  \
# freqCode            100,000.00    20,194,747.60          4,987.52
# refPeriodId         100,000.00         2,019.46              0.50
# refYear             100,000.00            52.00              0.00
# refMonth            100,000.00         2,019.46              0.50
# period              100,000.00           407.03            239.12
# flowDesc            100,000.00           429.79            255.00
# partnerDesc         100,000.00             0.00              0.00
# cmdDesc             100,000.00             0.00              0.00
# customsDesc         100,000.00             0.00              0.00
# mosCode             100,000.00             0.00              0.00
# motDesc             100,000.00            -1.00              0.00
# qtyUnitCode               0.00              NaN               NaN
# qtyUnitAbbr         100,000.00             0.00              0.00
# isQtyEstimated      100,000.00            -1.00              0.00
# altQtyUnitCode            0.00              NaN               NaN
# altQtyUnitAbbr      100,000.00             0.00              0.00
# isAltQtyEstimated    98,991.00             0.00              0.00
# isNetWgtEstimated   100,000.00             0.00              0.00
# isGrossWgtEstimated  75,161.00   820,518,904.96 18,854,936,771.28
# cifvalue             76,119.00 1,032,300,328.97 22,279,719,663.28
# fobvalue            100,000.00 1,305,726,900.75 23,954,691,018.32
# primaryValue        100,000.00             1.97              2.00
# isAggregate               0.00              NaN               NaN
#
#                               min           25%           50%           75%  \
# freqCode            20,190,101.00 20,190,101.00 20,190,101.00 20,200,101.00
# refPeriodId              2,019.00      2,019.00      2,019.00      2,020.00
# refYear                     52.00         52.00         52.00         52.00
# refMonth                 2,019.00      2,019.00      2,019.00      2,020.00
# period                       4.00        203.00        410.00        608.00
# flowDesc                     0.00        208.00        428.00        652.00
# partnerDesc                  0.00          0.00          0.00          0.00
# cmdDesc                      0.00          0.00          0.00          0.00
# customsDesc                  0.00          0.00          0.00          0.00
# mosCode                      0.00          0.00          0.00          0.00
# motDesc                     -1.00         -1.00         -1.00         -1.00
# qtyUnitCode                   NaN           NaN           NaN           NaN
# qtyUnitAbbr                  0.00          0.00          0.00          0.00
# isQtyEstimated              -1.00         -1.00         -1.00         -1.00
# altQtyUnitCode                NaN           NaN           NaN           NaN
# altQtyUnitAbbr               0.00          0.00          0.00          0.00
# isAltQtyEstimated            0.00          0.00          0.00          0.00
# isNetWgtEstimated            0.00          0.00          0.00          0.00
# isGrossWgtEstimated          0.00          0.00     82,275.13 10,599,715.00
# cifvalue                     0.00          0.00    299,995.00 19,381,688.29
# fobvalue                     0.01     80,850.55  2,406,471.97 50,724,987.66
# primaryValue                 0.00          0.00          0.00          4.00
# isAggregate                   NaN           NaN           NaN           NaN
#
#                                      max
# freqCode                   20,200,101.00
# refPeriodId                     2,020.00
# refYear                            52.00
# refMonth                        2,020.00
# period                            894.00
# flowDesc                          899.00
# partnerDesc                         0.00
# cmdDesc                             0.00
# customsDesc                         0.00
# mosCode                             0.00
# motDesc                            -1.00
# qtyUnitCode                          NaN
# qtyUnitAbbr                         0.00
# isQtyEstimated                     -1.00
# altQtyUnitCode                       NaN
# altQtyUnitAbbr                      0.00
# isAltQtyEstimated                   0.00
# isNetWgtEstimated                   0.00
# isGrossWgtEstimated 2,567,492,197,103.00
# cifvalue            2,589,098,353,298.00
# fobvalue            2,589,098,353,298.00
# primaryValue                        4.00
# isAggregate                          NaN

# %% [markdown]
# ### Clean column names

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('-', '_').str.replace(r"[ \-\/]+", "_", regex=True)     .str.replace(r"[^0-9a-z_]", "", regex=True)

# %% [markdown]
# ### Select relevant columns

# %%
df.head()
# Out:
#   typecode  freqcode  refperiodid  refyear  refmonth  period reportercode  \
# C        A  20190101         2019       52      2019       4          AFG
# C        A  20190101         2019       52      2019       4          AFG
# C        A  20190101         2019       52      2019       4          AFG
# C        A  20190101         2019       52      2019       4          AFG
# C        A  20190101         2019       52      2019       4          AFG
#
#    reporteriso reporterdesc flowcode  flowdesc partnercode      partneriso  \
# C  Afghanistan            M   Import         0         W00           World
# C  Afghanistan            M   Import        16         ASM  American Samoa
# C  Afghanistan            M   Import        20         AND         Andorra
# C  Afghanistan            M   Import        31         AZE      Azerbaijan
# C  Afghanistan            M   Import        32         ARG       Argentina
#
#    partnerdesc partner2code partner2iso partner2desc classificationcode  \
# C            0          W00       World           H4                 HS
# C            0          W00       World           H4                 HS
# C            0          W00       World           H4                 HS
# C            0          W00       World           H4                 HS
# C            0          W00       World           H4                 HS
#
#    classificationsearchcode isoriginalclassification          cmdcode  \
# C                      True                    TOTAL  All Commodities
# C                      True                    TOTAL  All Commodities
# C                      True                    TOTAL  All Commodities
# C                      True                    TOTAL  All Commodities
# C                      True                    TOTAL  All Commodities
#
#    cmddesc  aggrlevel isleaf customscode  customsdesc  moscode    motcode  \
# C        0      False    C00   TOTAL CPC            0        0  TOTAL MOT
# C        0      False    C00   TOTAL CPC            0        0  TOTAL MOT
# C        0      False    C00   TOTAL CPC            0        0  TOTAL MOT
# C        0      False    C00   TOTAL CPC            0        0  TOTAL MOT
# C        0      False    C00   TOTAL CPC            0        0  TOTAL MOT
#
#    motdesc  qtyunitcode  qtyunitabbr    qty  isqtyestimated  altqtyunitcode  \
# C       -1          NaN            0  False              -1             NaN
# C       -1          NaN            0  False              -1             NaN
# C       -1          NaN            0  False              -1             NaN
# C       -1          NaN            0  False              -1             NaN
# C       -1          NaN            0  False              -1             NaN
#
#    altqtyunitabbr  altqty  isaltqtyestimated  netwgt  isnetwgtestimated  \
# C               0   False               0.00    True                  0
# C               0   False               0.00    True                  0
# C               0   False               0.00    True                  0
# C               0   False               0.00    True                  0
# C               0   False               0.00   False                  0
#
#    grosswgt  isgrosswgtestimated  cifvalue         fobvalue  primaryvalue  \
# C     False     8,568,013,876.87      0.00 8,568,013,876.87             4
# C     False           614,220.56      0.00       614,220.56             4
# C     False           122,809.39      0.00       122,809.39             4
# C     False        48,473,684.35      0.00    48,473,684.35             4
# C     False           257,396.17      0.00       257,396.17             0
#
#    legacyestimationflag  isreported  isaggregate
# C                 False        True          NaN
# C                 False        True          NaN
# C                 False        True          NaN
# C                 False        True          NaN
# C                 False        True          NaN

# %%
print(df.columns)
# Out:
# Index(['typecode', 'freqcode', 'refperiodid', 'refyear', 'refmonth', 'period',
#        'reportercode', 'reporteriso', 'reporterdesc', 'flowcode', 'flowdesc',
#        'partnercode', 'partneriso', 'partnerdesc', 'partner2code',
#        'partner2iso', 'partner2desc', 'classificationcode',
#        'classificationsearchcode', 'isoriginalclassification', 'cmdcode',
#        'cmddesc', 'aggrlevel', 'isleaf', 'customscode', 'customsdesc',
#        'moscode', 'motcode', 'motdesc', 'qtyunitcode', 'qtyunitabbr', 'qty',
#        'isqtyestimated', 'altqtyunitcode', 'altqtyunitabbr', 'altqty',
#        'isaltqtyestimated', 'netwgt', 'isnetwgtestimated', 'grosswgt',
#        'isgrosswgtestimated', 'cifvalue', 'fobvalue', 'primaryvalue',
#        'legacyestimationflag', 'isreported', 'isaggregate'],
#       dtype='object')

# %% [markdown]
# ### Uninformative columns

# %%
# check for columns with single unique values (constant columns)
constant_cols = [col for col in df.columns if df[col].nunique() <= 1]
print("Constant Columns:")
print(constant_cols)
# Out:
# Constant Columns:
# ['typecode', 'refyear', 'partnerdesc', 'partner2code', 'partner2iso', 'classificationcode', 'classificationsearchcode', 'isoriginalclassification', 'cmdcode', 'cmddesc', 'aggrlevel', 'isleaf', 'customscode', 'customsdesc', 'moscode', 'motcode', 'motdesc', 'qtyunitcode', 'qtyunitabbr', 'qty', 'isqtyestimated', 'altqtyunitcode', 'altqtyunitabbr', 'altqty', 'isaltqtyestimated', 'isnetwgtestimated', 'grosswgt', 'legacyestimationflag', 'isreported', 'isaggregate']

# %%
# explore if these really have no information
for col in constant_cols:
    print(f"{col}: {df[col].unique()}")
# Out:
# typecode: ['A']
# refyear: [52]
# partnerdesc: [0]
# partner2code: ['W00']
# partner2iso: ['World']
# classificationcode: ['HS']
# classificationsearchcode: [ True]
# isoriginalclassification: ['TOTAL']
# cmdcode: ['All Commodities']
# cmddesc: [0]
# aggrlevel: [False]
# isleaf: ['C00']
# customscode: ['TOTAL CPC']
# customsdesc: [0]
# moscode: [0]
# motcode: ['TOTAL MOT']
# motdesc: [-1]
# qtyunitcode: [nan]
# qtyunitabbr: [0]
# qty: [False]
# isqtyestimated: [-1]
# altqtyunitcode: [nan]
# altqtyunitabbr: [0]
# altqty: [False]
# isaltqtyestimated: [ 0. nan]
# isnetwgtestimated: [0]
# grosswgt: [False]
# legacyestimationflag: [False]
# isreported: [ True]
# isaggregate: [nan]

# %%
# drop constant columns
print("Original DataFrame shape:", df.shape)
df = df.drop(columns=constant_cols)
print("New DataFrame shape:", df.shape)
# Out:
# Original DataFrame shape: (100000, 47)
# New DataFrame shape: (100000, 17)

# %%
# check columns with very low variance
numeric_cols = df.select_dtypes(include=[np.number]).columns
low_variance_cols = []
for col in numeric_cols:
    if df[col].std() < 0.01:  
        low_variance_cols.append(col)
print("Low Variance Columns:")
print(low_variance_cols)
# Out:
# Low Variance Columns:
# []

# %%
# columns with high cardinality
high_cardinality = df.nunique().sort_values(ascending=False)
print("Cardinality assorted columns:")
high_cardinality = high_cardinality[high_cardinality > 10]  # filter for columns with more than 10 unique values
print(high_cardinality)
# Out:
# Cardinality assorted columns:
# fobvalue               98922
# cifvalue               54243
# isgrosswgtestimated    53227
# flowdesc                 246
# partneriso               246
# partnercode              245
# period                   172
# reportercode             172
# reporteriso              172
# dtype: int64

# %%
# looks okay
df[high_cardinality.index]
# Out:
#            fobvalue      cifvalue  isgrosswgtestimated  flowdesc  \
# C  8,568,013,876.87          0.00     8,568,013,876.87         0
# C        614,220.56          0.00           614,220.56        16
# C        122,809.39          0.00           122,809.39        20
# C     48,473,684.35          0.00        48,473,684.35        31
# C        257,396.17          0.00           257,396.17        32
# ..              ...           ...                  ...       ...
# C     30,077,495.20 30,077,495.20                 0.00       854
# C     48,279,492.01 48,279,492.01                 0.00       858
# C     33,850,224.55 33,850,224.55                 0.00       860
# C      1,604,180.85  1,604,180.85                 0.00       862
# C         57,327.07     57,327.07                 0.00       882
#
#         partneriso partnercode  period reportercode  reporteriso
# C            World         W00       4          AFG  Afghanistan
# C   American Samoa         ASM       4          AFG  Afghanistan
# C          Andorra         AND       4          AFG  Afghanistan
# C       Azerbaijan         AZE       4          AFG  Afghanistan
# C        Argentina         ARG       4          AFG  Afghanistan
# ..             ...         ...     ...          ...          ...
# C     Burkina Faso         BFA     752          SWE       Sweden
# C          Uruguay         URY     752          SWE       Sweden
# C       Uzbekistan         UZB     752          SWE       Sweden
# C        Venezuela         VEN     752          SWE       Sweden
# C            Samoa         WSM     752          SWE       Sweden
#
# [100000 rows x 9 columns]

# %% [markdown]
# ### Missing values

# %%
# get missing percentage
missing_percentage = (df.isnull().sum() / df.shape[0]) * 100
print("Missing Values Percentage:")
print(missing_percentage[missing_percentage > 0])
# Out:
# Missing Values Percentage:
# isgrosswgtestimated   24.84
# cifvalue              23.88
# dtype: float64

# %%
df[missing_percentage[missing_percentage > 0].index].head()
# Out:
#    isgrosswgtestimated  cifvalue
# C     8,568,013,876.87      0.00
# C           614,220.56      0.00
# C           122,809.39      0.00
# C        48,473,684.35      0.00
# C           257,396.17      0.00

# %%
# 54% missing in cif value
df[df['cifvalue'] > 0].shape[0]/ df.shape[0] * 100
# Out:
# 54.659

# %% [markdown]
# ### Identify text or categorical columns

# %%
# idetnify text or categorical columns
text_cols = df.select_dtypes(include=['object']).columns
print("Text or Categorical Columns:")
print(text_cols)
# Out:
# Text or Categorical Columns:
# Index(['reportercode', 'reporteriso', 'reporterdesc', 'flowcode',
#        'partnercode', 'partneriso', 'partner2desc'],
#       dtype='object')

# %%
# these are just one word or very short text. Not really good for NLP but still good for now.
df[text_cols].head()
# Out:
#   reportercode  reporteriso reporterdesc flowcode partnercode      partneriso  \
# C          AFG  Afghanistan            M   Import         W00           World
# C          AFG  Afghanistan            M   Import         ASM  American Samoa
# C          AFG  Afghanistan            M   Import         AND         Andorra
# C          AFG  Afghanistan            M   Import         AZE      Azerbaijan
# C          AFG  Afghanistan            M   Import         ARG       Argentina
#
#   partner2desc
# C           H4
# C           H4
# C           H4
# C           H4
# C           H4

# %% [markdown]
# ### Save data

# %%
# save to ../data/processed
processed_data_path = '../data/processed'

df.to_csv(os.path.join(processed_data_path, 'trade_data_cleaned.csv'), index=False)

# %%
# create a sample data saved in processed_data_path
sample_data = df.sample(n=100, random_state=42)
sample_data.to_csv(os.path.join(processed_data_path, 'trade_data_sample.csv'), index=False)

# %%
df = df.drop(
    columns=['freqcode','refmonth','period','reportercode','reporterdesc','partnercode','cifvalue',
             'partner2desc','netwgt','primaryvalue']
    ).rename(columns={
        'reporteriso': 'reporter',
        'partneriso': 'partner',
        'refperiodid': 'year',
        'flowcode': "import_export"
        }
)

# %%
def clean_df(df):
    return df.drop(
    columns=['freqcode','refmonth','period','reportercode','reporterdesc','partnercode','cifvalue',
             'partner2desc','netwgt','primaryvalue']
    ).rename(columns={
        'reporteriso': 'reporter',
        'partneriso': 'partner',
        'refperiodid': 'year',
        'flowcode': "import_export"
        }
    )

# %% [markdown]
# ### Create data dictionary

# %%
# prepare data profile

def generate_column_profiles(df):
    profiles = {}
    for col in df.columns:
        profiles[col] = {
            "display_name": col.replace('_', ' ').title(),
            "description": f"Business purpose and meaning of {col}",
            "data_type": str(df[col].dtype),
            "example_values": df[col].dropna().unique().tolist()[:5],
            "missing_percentage": (df[col].isnull().sum() / df.shape[0]) * 100,
            "unique_values": df[col].nunique(),
            "sample_values": df[col].dropna().unique().tolist()[:5],
            "search_relevance": "high" if df[col].nunique() > 10 else "low",
            "rag_importance": "Essential for product queries" if col in ['trade_value_usd', 'cifvalue'] else "Useful for context",
            "relationships": []  # Placeholder for relationships
        }
    return profiles

# %%
def create_llm_prompt(column_name, column_profile, dataset_context):
    prompt = f"""
    You are an expert data analyst. Your task is to generate a detailed description for the column '{column_name}' in the dataset.
    
    Column Profile:
    - Display Name: {column_profile['display_name']}
    - Description: {column_profile['description']}
    - Data Type: {column_profile['data_type']}
    - Example Values: {', '.join(map(str, column_profile['example_values']))}
    - Missing Percentage: {column_profile['missing_percentage']}%
    - Unique Values: {column_profile['unique_values']}
    - Sample Values: {', '.join(map(str, column_profile['sample_values']))}
    - Search Relevance: {column_profile['search_relevance']}
    - RAG Importance: {column_profile['rag_importance']}
    
    Please provide:
    1. Business-friendly display name
    2. Clear description of what this column represents
    3. Business purpose and how it's used in trade context
    4. Importance level for search/query applications (High/Medium/Low)
    5. Relationship to other trade data fields

    Format as JSON:
    {{
        "display_name": "Human readable name",
        "description": "What this column represents",
        "business_purpose": "How this is used in trade/logistics",
        "search_importance": "High/Medium/Low",
        "notes": "Additional context or relationships"
    }}
    """
    return prompt

# %%
import json
def process_columns_for_dictionary(df, llm_function, batch_size=5):
    
    # generate profile for all columns
    column_profiles = generate_column_profiles(df)

    # process in batches
    columns = list(df.columns)
    data_dictionary = {}
    for i in range(0, len(columns), batch_size):
        batch_cols = columns[i:i+batch_size]
        print(f"Processing columns {i+1} to {i+len(batch_cols)}: {batch_cols}")

        for col in batch_cols:
            try:
                prompt = create_llm_prompt(col, column_profiles[col], "trade data context")

                llm_response = llm_function(prompt)

                # parse response
                column_dict = json.loads(llm_response)
                data_dictionary[col] = column_dict
                print(f"Processed column '{col}': {column_dict}")
            except Exception as e:
                print(f"Error processing column '{col}': {e}")
                data_dictionary[col] = {
                    "display_name": column_profiles[col]['display_name'],
                    "description": "Error processing this column",
                    "business_purpose": "",
                    "search_importance": "Unknown",
                    "notes": str(e)
                }
    return data_dictionary

# %%
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def call_openai_llm(prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            max_tokens=500,
            temperature=0.5
        )
        # Fix: Use .content instead of ['content']
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error calling OpenAI API: {e}")
        return f"Error: {str(e)}"
 
test_response = call_openai_llm("What is a trade value? Answer in one sentence.")
print("Test response:", test_response)
# Out:
# Test response: A trade value is the estimated worth or price of a particular item or asset in a trade transaction.

# %%
def create_data_dictionary(df, batch_size=5):

    print("Generating data dictionary...")

    column_profiles = generate_column_profiles(df)

    columns = list(df.columns)
    data_dictionary = {}

    print("Processing columns in batches...")
    for i in range(0, len(columns), batch_size):
        batch_cols = columns[i:i+batch_size]
        print(f"Processing columns {i+1} to {i+len(batch_cols)}: {batch_cols}")

        for col in batch_cols:
            try:
                prompt = create_llm_prompt(col, column_profiles[col], "trade data context")

                # call openAI
                print(f"Calling OpenAI for column '{col}'...")
                llm_response = call_openai_llm(prompt)

                # try to parse the response
                try:
                    column_dict = json.loads(llm_response)
                    data_dictionary[col] = column_dict
                    print(f"Processed column '{col}': {column_dict}")
                except json.JSONDecodeError as e:
                    print(f"Error parsing JSON for column '{col}': {e}")
                    data_dictionary[col] = {
                        "display_name": column_profiles[col]['display_name'],
                        "description": "Error parsing response",
                        "business_purpose": "",
                        "search_importance": "Unknown",
                        "notes": str(e)
                    }
            except Exception as e:
                print(f"Error processing column '{col}': {e}")
                data_dictionary[col] = {
                    "display_name": column_profiles[col]['display_name'],
                    "description": "Error processing this column",
                    "business_purpose": "",
                    "search_importance": "Unknown",
                    "notes": str(e)
                }

    print("Data dictionary generation complete.")
    return data_dictionary

# %%
data_dictionary = create_data_dictionary(df, batch_size= 2)
# Out:
# Generating data dictionary...
# Processing columns in batches...
# Processing columns 1 to 2: ['year', 'reporter']
# Calling OpenAI for column 'year'...
# Processed column 'year': {'display_name': 'Year', 'description': 'The calendar year in which a trade transaction or event occurred', 'business_purpose': 'The year column provides a chronological reference point for analyzing trends, seasonality, and performance of trade activities over time. It is used to track annual performance, plan for future years, and compare year-over-year growth.', 'search_importance': 'Low', 'notes': 'The year column can be related to other time-related fields such as month, quarter, or date to provide more granular insights into trade data.'}
# Calling OpenAI for column 'reporter'...
# Processed column 'reporter': {'display_name': 'Reporter', 'description': 'The country or entity that reports the trade data', 'business_purpose': "The 'reporter' column is crucial in trade and logistics as it indicates the country or entity providing the trade data. This information is used to analyze trade patterns, monitor trade agreements, and assess the economic performance of different countries.", 'search_importance': 'High', 'notes': "The 'reporter' column may be related to other trade data fields such as 'partner', 'product', and 'value' to provide a comprehensive view of trade relationships and flows."}
# Processing columns 3 to 4: ['import_export', 'flowdesc']
# Calling OpenAI for column 'import_export'...
# Processed column 'import_export': {'display_name': 'Import Export Status', 'description': 'This column indicates whether the transaction is an import or export', 'business_purpose': 'In trade and logistics, this field helps in tracking the direction of goods movement, determining customs duties, and monitoring trade balance.', 'search_importance': 'Low', 'notes': 'This field can be related to other trade data fields such as country of origin/destination, product type, and quantity.'}
# Calling OpenAI for column 'flowdesc'...
# Processed column 'flowdesc': {'display_name': 'Flow Description', 'description': 'The numerical code representing the type of flow for a trade transaction', 'business_purpose': 'Flowdesc is used to categorize the type of trade flow such as imports, exports, re-exports, etc. This information is important for analyzing trade patterns, identifying trends, and understanding the nature of trade activities.', 'search_importance': 'High', 'notes': 'Flowdesc may be related to other trade data fields such as country of origin/destination, commodity code, and trade value to provide a comprehensive view of trade activities.'}
# Processing columns 5 to 6: ['partner', 'isgrosswgtestimated']
# Calling OpenAI for column 'partner'...
# Processed column 'partner': {'display_name': 'Partner', 'description': 'The country or entity that is a trading partner in a business transaction', 'business_purpose': "The 'partner' column identifies the specific country or entity that is involved in a trade deal, import/export transaction, or business partnership. It provides context on the geographical location of the trading partner and helps in analyzing trade relationships and patterns.", 'search_importance': 'High', 'notes': "The 'partner' column may be related to other trade data fields such as 'country of origin', 'destination country', 'importer', and 'exporter' to provide a comprehensive view of the trade network."}
# Calling OpenAI for column 'isgrosswgtestimated'...
# Processed column 'isgrosswgtestimated': {'display_name': 'Is Gross Weight Estimated', 'description': 'This column indicates whether the gross weight of a trade item is estimated or not.', 'business_purpose': 'In trade and logistics, knowing whether the gross weight is estimated or not can impact shipping costs, customs declarations, and overall supply chain efficiency.', 'search_importance': 'High', 'notes': 'This field can be related to other trade data fields such as net weight, volume, and dimensions to ensure accurate and efficient trade operations.'}
# Processing columns 7 to 7: ['fobvalue']
# Calling OpenAI for column 'fobvalue'...
# Processed column 'fobvalue': {'display_name': 'FOB Value', 'description': 'The FOB value represents the total value of goods being exported or imported excluding the costs of transportation, insurance, and other expenses beyond the point of origin.', 'business_purpose': 'The FOB value is crucial in trade transactions as it determines the value of goods at the point of export or import. It is used for customs clearance, calculating duties and taxes, and assessing the overall value of the trade transaction.', 'search_importance': 'High', 'notes': 'The FOB value is often used in conjunction with other trade data fields such as CIF value, freight charges, and total landed cost to provide a comprehensive view of the financial aspects of international trade.'}
# Data dictionary generation complete.

# %%
pd.DataFrame(data_dictionary)
# Out:
#                                                                 year  \
# display_name                                                    Year
# description        The calendar year in which a trade transaction...
# business_purpose   The year column provides a chronological refer...
# search_importance                                                Low
# notes              The year column can be related to other time-r...
#
#                                                             reporter  \
# display_name                                                Reporter
# description        The country or entity that reports the trade data
# business_purpose   The 'reporter' column is crucial in trade and ...
# search_importance                                               High
# notes              The 'reporter' column may be related to other ...
#
#                                                        import_export  \
# display_name                                    Import Export Status
# description        This column indicates whether the transaction ...
# business_purpose   In trade and logistics, this field helps in tr...
# search_importance                                                Low
# notes              This field can be related to other trade data ...
#
#                                                             flowdesc  \
# display_name                                        Flow Description
# description        The numerical code representing the type of fl...
# business_purpose   Flowdesc is used to categorize the type of tra...
# search_importance                                               High
# notes              Flowdesc may be related to other trade data fi...
#
#                                                              partner  \
# display_name                                                 Partner
# description        The country or entity that is a trading partne...
# business_purpose   The 'partner' column identifies the specific c...
# search_importance                                               High
# notes              The 'partner' column may be related to other t...
#
#                                                  isgrosswgtestimated  \
# display_name                               Is Gross Weight Estimated
# description        This column indicates whether the gross weight...
# business_purpose   In trade and logistics, knowing whether the gr...
# search_importance                                               High
# notes              This field can be related to other trade data ...
#
#                                                             fobvalue
# display_name                                               FOB Value
# description        The FOB value represents the total value of go...
# business_purpose   The FOB value is crucial in trade transactions...
# search_importance                                               High
# notes              The FOB value is often used in conjunction wit...

# %%
# save as csv
pd.DataFrame.from_dict(data_dictionary, orient='index').to_csv("data_dictionary.csv")

# %% [markdown]
# ### Get final columns

# %%
# final columns
final_columns = df.columns.tolist()

# %% [markdown]
# ### Combine data

# %%
raw_data_path = '../data/raw'

# get all files in raw_data_path
raw_files = [f for f in os.listdir(raw_data_path) if os.path.isfile(os.path.join(raw_data_path, f))]
raw_files
# Out:
# ['TradeData_8_2_2025_13_44_38.csv',
#  'TradeData_8_2_2025_15_26_31.csv',
#  'TradeData_8_2_2025_15_21_12.csv',
#  'TradeData_8_2_2025_15_27_27.csv']

# %%
df_combined = pd.DataFrame()
for file in raw_files:
    file_path = os.path.join(raw_data_path, file)
    print(f"Processing file: {file_path}")
    temp_df = pd.read_csv(file_path, encoding="latin-1", engine="python")
    temp_df.columns = temp_df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('-', '_').str.replace(r"[ \-\/]+", "_", regex=True)     .str.replace(r"[^0-9a-z_]", "", regex=True)
    temp_df = clean_df(temp_df)  # apply cleaning function
    temp_df = temp_df[final_columns]  # ensure only final columns are kept
    print(f"Columns after processing: {temp_df.columns.tolist()}")
    df_combined = pd.concat([df_combined, temp_df], ignore_index=True)
# Out:
# Processing file: ../data/raw/TradeData_8_2_2025_13_44_38.csv
# Columns after processing: ['year', 'reporter', 'import_export', 'flowdesc', 'partner', 'isgrosswgtestimated', 'fobvalue']
# Processing file: ../data/raw/TradeData_8_2_2025_15_26_31.csv
# Columns after processing: ['year', 'reporter', 'import_export', 'flowdesc', 'partner', 'isgrosswgtestimated', 'fobvalue']
# Processing file: ../data/raw/TradeData_8_2_2025_15_21_12.csv
# Columns after processing: ['year', 'reporter', 'import_export', 'flowdesc', 'partner', 'isgrosswgtestimated', 'fobvalue']
# Processing file: ../data/raw/TradeData_8_2_2025_15_27_27.csv
# Columns after processing: ['year', 'reporter', 'import_export', 'flowdesc', 'partner', 'isgrosswgtestimated', 'fobvalue']

# %%
processed_data_path = '../data/processed'
df_combined.sample(1000).to_csv(os.path.join(processed_data_path, 'trade_data_combined_sample.csv'), index=False)

# %%
# save to ../data/processed

df_combined.to_csv(os.path.join(processed_data_path, 'trade_data_combined.csv'), index=False)

# %%
df_combined['year'].value_counts()
# Out:
# year
# 2017    53985
# 2019    53534
# 2021    53153
# 2023    50312
# 2022    46847
# 2020    46466
# 2018    46015
# 2024    33214
# Name: count, dtype: int64

# %% [markdown]
# ### Save to parquet

# %%
df_combined.to_parquet('../data/processed/trade_data_cleaned.parquet')
